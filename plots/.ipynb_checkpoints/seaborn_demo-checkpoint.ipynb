# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')

# %% [markdown]
# ### Categorical Plots

# %% [markdown]
# #### *boxplot( )*

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, showfliers = False)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', showfliers = False, showmeans = True)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', showfliers = False, showmeans = True, meanline = True, width = 0.5)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### *Countplot( )*

# %%
sns.countplot(x = 'day', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x = 'day', data = tips, hue = 'sex')
# Out:
# <AxesSubplot:xlabel='day', ylabel='count'>

# %%
sns.countplot(x = 'smoker', data = tips, hue = 'day')
# Out:
# <AxesSubplot:xlabel='smoker', ylabel='count'>

# %% [markdown]
# #### *barplot( )*

# %% [markdown]
# #### Method 1

# %%
sns.barplot(x = 'day', y = 'total_bill', data = tips, hue = 'size', ci = False, estimator = sum )
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# #### Method 2

# %%
ax = tips.pivot_table(index = 'day', columns = 'size', values = 'total_bill', aggfunc = 'sum')
ax
# Out:
# size      1       2       3       4      5      6
# day
# Thur  10.07  727.53   76.64  149.75  41.19  91.15
# Fri    8.58  261.15   15.98   40.17    NaN    NaN
# Sat   10.32  892.37  459.17  388.39  28.15    NaN
# Sun     NaN  684.84  332.76  480.39  81.00  48.17

# %%
ax.plot.bar()
# Out:
# <AxesSubplot:xlabel='day'>

# %% [markdown]
# #### *Catplot( )*

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, kind = 'bar', ci = False, estimator = sum)

# %%
sns.catplot(x = 'day', y = 'total_bill', data = tips, col = 'smoker', kind = 'bar', ci = False, estimator = sum)

# %%
ax = sns.catplot(x = 'size', y = 'total_bill', data = tips, col = 'day', kind = 'bar', ci = False)
ax.fig.suptitle('Day Wise Average Total Bill for Different Sizes')
ax.fig.subplots_adjust(top = .85)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-1285dc0121a4> in <module>
# ----> 1 ax = sns.catplot(x = 'size', y = 'total_bill', data = tips, col = 'day', kind = 'bar', ci = False, estimator = mean)
#       2 ax.fig.suptitle('Day Wise Average Total Bill for Different Sizes')
#       3 ax.fig.subplots_adjust(top = .85)
#
# NameError: name 'mean' is not defined

# %%
ax = sns.catplot(x = 'size', y = 'total_bill', data = tips, col = 'day', row = 'smoker', kind = 'bar', ci = False)
