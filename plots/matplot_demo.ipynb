# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib

# %%
plt.isinteractive()
# Out:
# True

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
day_total = tips.groupby('day')['total_bill'].sum()
day_total
# Out:
# day
# Thur    1096.33
# Fri      325.88
# Sat     1778.40
# Sun     1627.16
# Name: total_bill, dtype: float64

# %%
day_total = tips.groupby('day', as_index = False)['total_bill'].sum()
day_total
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %% [markdown]
# ### Line Graph

# %%
day_total.plot.line()
# Out:
# <AxesSubplot:>

# %%
plt.plot(day_total['day'], day_total['total_bill']) # plt.plot(X axis, Y axis)
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.title('Day Vs Total Bill')
# Out:
# Text(0.5, 1.0, 'Day Vs Total Bill')

# %%
plt.plot(day_total['day'], day_total['total_bill'], 'bD--') 
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.title('Day Vs Total Bill')
# Out:
# Text(0.5, 1.0, 'Day Vs Total Bill')

# %%
male = tips[tips.sex == 'Male']
male_total = male.groupby('day', as_index = False)['total_bill'].sum()

female = tips[tips.sex == 'Female']
female_total = female.groupby('day', as_index = False)['total_bill'].sum()

plt.plot(male_total['day'], male_total['total_bill'], '--',label = 'male')
plt.plot(female_total['day'], female_total['total_bill'], label = 'female')
plt.legend()
#plt.legend(loc = 'upper right')
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.title('Sex Vs Total Bill')
#plt.ylim(0,1500)
# Out:
# Text(0.5, 1.0, 'Sex Vs Total Bill')

# %% [markdown]
# ### Bar Graph

# %%
plt.bar(day_total['day'], day_total['total_bill'], color = 'orange', width = .5)
plt.xlabel('Day')
plt.ylabel('Total Bill')
plt.title('Day Vs Total Bill')
# Out:
# Text(0.5, 1.0, 'Day Vs Total Bill')

# %% [markdown]
# ### Pie Chart

# %%
plt.pie(day_total['total_bill'], labels = day_total['day'])
plt.title('Day Vs Total Bill')
# Out:
# Text(0.5, 1.0, 'Day Vs Total Bill')

# %%
plt.pie(day_total['total_bill'], labels = day_total['day'], autopct = "%.2f")
plt.title('Day Vs Total Bill')
# Out:
# Text(0.5, 1.0, 'Day Vs Total Bill')

# %%
plt.pie(day_total['total_bill'], labels = day_total['day'], autopct = "%.2f", explode = (0,0,0,0.1), textprops = {'color' : 'black'})
plt.title('Day Vs Total Bill')
# Out:
# Text(0.5, 1.0, 'Day Vs Total Bill')

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(tips['total_bill'], tips['tip'], c = 'orange')
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Total Bill Vs Tip')
# Out:
# Text(0.5, 1.0, 'Total Bill Vs Tip')

# %%
males = tips.loc[tips.sex == 'Male', :]
females = tips.loc[tips.sex == 'Female', :]

# %%
males.head()
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2
# 5       25.29  4.71  Male     No  Sun  Dinner     4
# 6        8.77  2.00  Male     No  Sun  Dinner     2

# %%
plt.scatter(males['total_bill'], males['tip'], label = 'Male', marker = '+')
plt.scatter(females['total_bill'], females['tip'], c = 'orange', label = 'Female', marker = '.')
plt.legend()
plt.xlabel('Total Bill')
plt.ylabel('Tip')
plt.title('Total Bill Vs Tip')
plt.gcf().set_size_inches(10,5)

# %% [markdown]
# ### Box Plot

# %%
plt.boxplot(tips['total_bill'])
plt.title('Total Bill')
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %%
prop = {'color':'red', 'linewidth' : 3, 'linestyle' : 'solid'} 
plt.boxplot(tips['total_bill'], boxprops = prop)
plt.title('Total Bill')
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %% [markdown]
#  ### Histogram

# %%
plt.hist(tips['total_bill'])
plt.xlabel('Total Bill')
plt.ylabel('Count')
plt.title('Total Bill Distribution')
# Out:
# Text(0.5, 1.0, 'Total Bill Distribution')

# %%
plt.hist(tips['tip'])
plt.xlabel('Tip')
plt.ylabel('Count')
plt.title('Tip Distribution')
# Out:
# Text(0.5, 1.0, 'Tip Distribution')

# %%
plt.hist(tips['total_bill'], bins = range(0,60,10))
plt.title('Total Bill')
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %%
plt.hist(tips['total_bill'], bins = range(0,60,10), orientation = 'horizontal')
plt.title('Total Bill')
# Out:
# Text(0.5, 1.0, 'Total Bill')

# %% [markdown]
# ### Object API

# %%
day_total = tips.groupby('day', as_index = False)['total_bill'].sum()
day_total
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
ax = plt.subplot()
ax.bar(day_total['day'], day_total['total_bill'])
ax.set_xlabel('Day')
ax.set_ylabel('Total Bill')
ax.set_title('Day Wise Total Bill')
# Out:
# Text(0.5, 1.0, 'Day Wise Total Bill')

# %%
fig,ax = plt.subplots(1,2) # 1 row 2 columns
fig.suptitle("Day Wise Total", fontsize = 14, color = 'Blue')
fig.set_size_inches(15,5)
# Axes 1 --> Bar Graph
ax[0].bar(day_total['day'], day_total['total_bill'])
ax[0].set_xlabel('Day')
ax[0].set_ylabel('Total Bill')
# Axes 2 --> Line Graph
ax[1].plot(day_total['day'], day_total['total_bill'], 'o--')
ax[1].set_xlabel('Day')
ax[1].set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %% [markdown]
# ### Text

# %%
plt.plot(day_total['day'], day_total['total_bill'], 'o--')
days = day_total['day']
totals = day_total['total_bill']

# Set labels for markers
for (x,y) in zip(days,totals):
    plt.text(x,y+100, f"{y:.0f}")
    
plt.gcf().set_size_inches(10,5)

# %%
countries = pd.read_json("https://restcountries.eu/rest/v2/all")

# %% [markdown]
# #### Method 1

# %%
top_countries = countries.nlargest(5, 'population')
areas = top_countries['area']
populations = top_countries['population']
plt.scatter(top_countries['area'], top_countries['population'])
plt.xlabel('Area')
plt.ylabel('Population')

for (x,y) in zip(areas, populations):
    plt.text(x+100,y+100,f"{y}")

    plt.gcf().set_size_inches(10,5)

# %% [markdown]
# #### Method 2

# %%
top_countries = countries.nlargest(5,'population')
plt.scatter(x = top_countries['area'], y = top_countries['population']) 
plt.xlabel("Area")
plt.ylabel("Population")

for i in tc.index:
     pic = top_countries.loc[i,'population'] // 10000000 # Population in crores
     plt.text(top_countries.loc[i,'area']+100000, top_countries.loc[i,'population'], f"{top_countries.loc[i,'alpha3Code']} - {pic} CR")
    
plt.gcf().set_size_inches(10,5) # gcf() --> Get current figure

# %%
smoker_total = tips.pivot_table(index = 'day', columns = 'smoker', values = 'total_bill', aggfunc = 'sum')
smoker_total
# Out:
# smoker     Yes       No
# day
# Thur    326.24   770.09
# Fri     252.20    73.68
# Sat     893.62   884.78
# Sun     458.28  1168.88

# %%
ax = plt.subplot()
ax.bar(smoker_total.index, height = smoker_total['Yes'], label = 'Smokers')
ax.bar(smoker_total.index, height = smoker_total['No'], bottom = smoker_total["Yes"], label = 'Non Smokers')
ax.legend()

# %%
smoker_total.plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='day'>

# %%
day_total = tips.pivot_table(index = 'sex', columns = 'day', values = 'total_bill', aggfunc = 'sum')
day_total.plot.bar(stacked = True)
# Out:
# <AxesSubplot:xlabel='sex'>

# %% [markdown]
# ### Multibar Graph

# %%
ax = smoker_total.plot.bar()
ax.set_xlabel('Day')
ax.set_ylabel('Total Bill')
# Out:
# Text(0, 0.5, 'Total Bill')

# %%
smoker_total.plot.line()
# Out:
# <AxesSubplot:xlabel='day'>

# %%
smoker_total.plot.line(subplots = True)
# Out:
# array([<AxesSubplot:xlabel='day'>, <AxesSubplot:xlabel='day'>],
#       dtype=object)

# %% [markdown]
# #### *Using crosstab( )*

# %%
totals = pd.crosstab(tips['sex'], tips['day'], tips['total_bill'], aggfunc = 'sum')
totals
# Out:
# day       Thur     Fri      Sat      Sun
# sex
# Male    561.44  198.57  1227.35  1269.46
# Female  534.89  127.31   551.05   357.70

# %% [markdown]
# #### *Using pivot_table( )*

# %%
totals = tips.pivot_table(index = 'sex', columns = 'day', values = 'total_bill', aggfunc = 'sum')
totals
# Out:
# day       Thur     Fri      Sat      Sun
# sex
# Male    561.44  198.57  1227.35  1269.46
# Female  534.89  127.31   551.05   357.70

# %%
totals.plot(kind = 'barh', figsize = (10,5))
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
totals.plot(kind = 'bar', figsize = (10,5))
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
ax = tips.hist()
ax[0,1].set_title("Hello")
# Out:
# Text(0.5, 1.0, 'Hello')

# %%
ax = tips[['total_bill', 'tip']].hist()

# %%
countries['region'].value_counts()
# Out:
# Africa      60
# Americas    57
# Europe      53
# Asia        50
# Oceania     27
#              2
# Polar        1
# Name: region, dtype: int64

# %% [markdown]
# ### **Top 10** Countries in **Asia**

# %% [markdown]
# #### Method 1

# %%
asia_top = countries.loc[countries.region == 'Asia', ['name', 'population', 'area']].sort_values('population', ascending = False).head(10)
asia_top
# Out:
#                            name  population       area
# 48                        China  1377422166  9640011.0
# 104                       India  1295210000  3287590.0
# 105                   Indonesia   258705000  1904569.0
# 169                    Pakistan   194125062   881912.0
# 18                   Bangladesh   161006790   147570.0
# 114                       Japan   126960000   377930.0
# 176                 Philippines   103279800   342353.0
# 244                    Viet Nam    92700000   331212.0
# 107  Iran (Islamic Republic of)    79369900  1648195.0
# 231                      Turkey    78741053   783562.0

# %% [markdown]
# #### Method 2

# %%
asia_top = countries.loc[countries.region == 'Asia', ['name', 'population', 'area']].nlargest(10, 'population')
asia_top
# Out:
#                            name  population       area
# 48                        China  1377422166  9640011.0
# 104                       India  1295210000  3287590.0
# 105                   Indonesia   258705000  1904569.0
# 169                    Pakistan   194125062   881912.0
# 18                   Bangladesh   161006790   147570.0
# 114                       Japan   126960000   377930.0
# 176                 Philippines   103279800   342353.0
# 244                    Viet Nam    92700000   331212.0
# 107  Iran (Islamic Republic of)    79369900  1648195.0
# 231                      Turkey    78741053   783562.0

# %%
ax = asia_top['population'].plot.bar()
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(2,1)
fig.set_size_inches(20,15)

ax[0].bar(asia_top['name'], asia_top['population'])
ax[0].set_xlabel('Country')
ax[0].set_ylabel('Population')
ax[0].set_xticklabels(asia_top.name, rotation = 'vertical')

ax[1].bar(asia_top['name'], asia_top['area'])
ax[1].set_xlabel('Country')
ax[1].set_ylabel('Area')
ax[1].set_xticklabels(asia_top.name, rotation = 90)
# Out:
# <ipython-input-241-3ac640804f51>:7: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[0].set_xticklabels(asia_top.name, rotation = 'vertical')
# <ipython-input-241-3ac640804f51>:12: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax[1].set_xticklabels(asia_top.name, rotation = 90)
# [Text(0, 0, 'China'),
#  Text(1, 0, 'India'),
#  Text(2, 0, 'Indonesia'),
#  Text(3, 0, 'Pakistan'),
#  Text(4, 0, 'Bangladesh'),
#  Text(5, 0, 'Japan'),
#  Text(6, 0, 'Philippines'),
#  Text(7, 0, 'Viet Nam'),
#  Text(8, 0, 'Iran (Islamic Republic of)'),
#  Text(9, 0, 'Turkey')]
